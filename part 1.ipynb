# %% [markdown]
# # Part 1

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')

# %% [markdown]
# # Membuat Plotting Sederhana

# %% [markdown]
# ## Membuat Sebuah Figure Yang Memiliki Sebuah Axes Melakukan Plotting Data Pada Axes

# %%
# Pesipan Sample Data

x = [1,2,3,4]
y = [1,4,2,3]

fig, ax = plt.subplots() # Membuat Sebuah Figure Dan Axes
ax.plot(x,y) # Melakukan Plotting Data Pada Axes

# %% [markdown]
# # Alternatif Lain Kita Bisa Memanfaatkan Method plot() Pada Pyplot Untuk Melakukan Plotting Sederhana

# %%
# Pesipan Sample Data

x = [1,2,3,4]
y = [1,4,2,3]

plt.plot(x,y)

# %% [markdown]
# # Berikut Adalah Beberapa Cara Untuk Membuat Figure Dan Axes

# %%
fig = plt.figure() # Membuat Sebuah Figure Tanpa Axes

# %%
fig, ax = plt.subplots() # Membuat Figure Dengan Sebuah Axes

# %%
fig, ax = plt.subplots(nrows=2,ncols=3) # Membuat Figure Dengan 2x3 Grid Axes

# %% [markdown]
# # Mengenal Object Oriented Style Untuk Melakukan plotting

# %% [markdown]
# ## Secara Eksplisti Membuah Figure Dan Axes Dan Memanggil Methods Dari Keduanya

# %%
x = np.linspace(0,2,100)
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
# ...

# %%
fig, ax = plt.subplots() # Membuat Sebuah Figure Dan Axes

# Plotting Tiga Variant Data Pada Axes
ax.plot(x,x,label='linear')
ax.plot(x,x**2,label='Quadartic')
ax.plot(x,x**3,label='Qubic')

ax.set_xlabel('Sumbu X') # Menyertakan xlabel Pada Axes
ax.set_ylabel('Sumbu Y') # Menyertakan ylabel Pada Axes
ax.set_title('Simple Plot') # Menyertakan Title Pada Axes

ax.legend() # Menyertakan Legend

# %% [markdown]
# # Mengenal Pyplot Style

# %% [markdown]
# ## Mengandalkan Pyplot Untuk Membuat Dan Mengelola Figures Dan Axes Serta Menggunakan Fungsi Pada Pyplot Untuk Melakukan plotting

# %%
x = np.linspace(0,2,100)
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
# ...

# %%
plt.plot(x,x,label='Linear')
plt.plot(x,x**2,label='Quadratic')
plt.plot(x,x**3,label='Qubic')

plt.title('Simple Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.legend()
plt.show()
